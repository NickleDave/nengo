# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1397791205" href="javascript:toggle_input_1397791205()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1397791205;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1397791205 = document.getElementById("1397791205");
#                 var cell = link_1397791205;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1397791205;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1397791205 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1397791205 = cell.previousElementSibling;
#                 }
#                 input_1397791205.style.display = "none"; // hide
#
#                 toggle_input_1397791205 = function() {
#                     if (input_1397791205.style.display == "none") {
#                         input_1397791205.style.display = ""; // show
#                         link_1397791205.innerHTML = "Hide Input";
#                     } else {
#                         input_1397791205.style.display = "none"; // hide
#                         link_1397791205.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1397791205 = $("a[id='1397791205']");
#                 var cell_1397791205 = link_1397791205.parents("div.cell:first");
#                 if (cell_1397791205.length == 0) {
#                     cell_1397791205 = link_1397791205.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1397791205 = cell_1397791205.children("div.input");
#                 if (input_1397791205.length == 0) {
#                     input_1397791205 = cell_1397791205.prev("div.nbinput");
#                 }
#                 input_1397791205.hide();
#
#                 toggle_input_1397791205 = function() {
#                     if (input_1397791205.is(':hidden')) {
#                         input_1397791205.slideDown();
#                         link_1397791205[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1397791205.slideUp();
#                         link_1397791205[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1991996927" href="javascript:toggle_input_1991996927()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1991996927;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1991996927 = document.getElementById("1991996927");
#                 var cell = link_1991996927;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1991996927;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1991996927 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1991996927 = cell.previousElementSibling;
#                 }
#                 input_1991996927.style.display = "none"; // hide
#
#                 toggle_input_1991996927 = function() {
#                     if (input_1991996927.style.display == "none") {
#                         input_1991996927.style.display = ""; // show
#                         link_1991996927.innerHTML = "Hide Input";
#                     } else {
#                         input_1991996927.style.display = "none"; // hide
#                         link_1991996927.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1991996927 = $("a[id='1991996927']");
#                 var cell_1991996927 = link_1991996927.parents("div.cell:first");
#                 if (cell_1991996927.length == 0) {
#                     cell_1991996927 = link_1991996927.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1991996927 = cell_1991996927.children("div.input");
#                 if (input_1991996927.length == 0) {
#                     input_1991996927 = cell_1991996927.prev("div.nbinput");
#                 }
#                 input_1991996927.hide();
#
#                 toggle_input_1991996927 = function() {
#                     if (input_1991996927.is(':hidden')) {
#                         input_1991996927.slideDown();
#                         link_1991996927[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1991996927.slideUp();
#                         link_1991996927[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="2130327854" href="javascript:toggle_input_2130327854()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2130327854;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2130327854 = document.getElementById("2130327854");
#                 var cell = link_2130327854;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2130327854;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2130327854 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2130327854 = cell.previousElementSibling;
#                 }
#                 input_2130327854.style.display = "none"; // hide
#
#                 toggle_input_2130327854 = function() {
#                     if (input_2130327854.style.display == "none") {
#                         input_2130327854.style.display = ""; // show
#                         link_2130327854.innerHTML = "Hide Input";
#                     } else {
#                         input_2130327854.style.display = "none"; // hide
#                         link_2130327854.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2130327854 = $("a[id='2130327854']");
#                 var cell_2130327854 = link_2130327854.parents("div.cell:first");
#                 if (cell_2130327854.length == 0) {
#                     cell_2130327854 = link_2130327854.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2130327854 = cell_2130327854.children("div.input");
#                 if (input_2130327854.length == 0) {
#                     input_2130327854 = cell_2130327854.prev("div.nbinput");
#                 }
#                 input_2130327854.hide();
#
#                 toggle_input_2130327854 = function() {
#                     if (input_2130327854.is(':hidden')) {
#                         input_2130327854.slideDown();
#                         link_2130327854[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2130327854.slideUp();
#                         link_2130327854[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="736183199" href="javascript:toggle_input_736183199()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_736183199;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_736183199 = document.getElementById("736183199");
#                 var cell = link_736183199;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_736183199;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_736183199 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_736183199 = cell.previousElementSibling;
#                 }
#                 input_736183199.style.display = "none"; // hide
#
#                 toggle_input_736183199 = function() {
#                     if (input_736183199.style.display == "none") {
#                         input_736183199.style.display = ""; // show
#                         link_736183199.innerHTML = "Hide Input";
#                     } else {
#                         input_736183199.style.display = "none"; // hide
#                         link_736183199.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_736183199 = $("a[id='736183199']");
#                 var cell_736183199 = link_736183199.parents("div.cell:first");
#                 if (cell_736183199.length == 0) {
#                     cell_736183199 = link_736183199.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_736183199 = cell_736183199.children("div.input");
#                 if (input_736183199.length == 0) {
#                     input_736183199 = cell_736183199.prev("div.nbinput");
#                 }
#                 input_736183199.hide();
#
#                 toggle_input_736183199 = function() {
#                     if (input_736183199.is(':hidden')) {
#                         input_736183199.slideDown();
#                         link_736183199[0].innerHTML = "Hide Input";
#                     } else {
#                         input_736183199.slideUp();
#                         link_736183199[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="798981683" href="javascript:toggle_input_798981683()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_798981683;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_798981683 = document.getElementById("798981683");
#                 var cell = link_798981683;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_798981683;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_798981683 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_798981683 = cell.previousElementSibling;
#                 }
#                 input_798981683.style.display = "none"; // hide
#
#                 toggle_input_798981683 = function() {
#                     if (input_798981683.style.display == "none") {
#                         input_798981683.style.display = ""; // show
#                         link_798981683.innerHTML = "Hide Input";
#                     } else {
#                         input_798981683.style.display = "none"; // hide
#                         link_798981683.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_798981683 = $("a[id='798981683']");
#                 var cell_798981683 = link_798981683.parents("div.cell:first");
#                 if (cell_798981683.length == 0) {
#                     cell_798981683 = link_798981683.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_798981683 = cell_798981683.children("div.input");
#                 if (input_798981683.length == 0) {
#                     input_798981683 = cell_798981683.prev("div.nbinput");
#                 }
#                 input_798981683.hide();
#
#                 toggle_input_798981683 = function() {
#                     if (input_798981683.is(':hidden')) {
#                         input_798981683.slideDown();
#                         link_798981683[0].innerHTML = "Hide Input";
#                     } else {
#                         input_798981683.slideUp();
#                         link_798981683[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="841272109" href="javascript:toggle_input_841272109()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_841272109;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_841272109 = document.getElementById("841272109");
#                 var cell = link_841272109;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_841272109;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_841272109 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_841272109 = cell.previousElementSibling;
#                 }
#                 input_841272109.style.display = "none"; // hide
#
#                 toggle_input_841272109 = function() {
#                     if (input_841272109.style.display == "none") {
#                         input_841272109.style.display = ""; // show
#                         link_841272109.innerHTML = "Hide Input";
#                     } else {
#                         input_841272109.style.display = "none"; // hide
#                         link_841272109.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_841272109 = $("a[id='841272109']");
#                 var cell_841272109 = link_841272109.parents("div.cell:first");
#                 if (cell_841272109.length == 0) {
#                     cell_841272109 = link_841272109.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_841272109 = cell_841272109.children("div.input");
#                 if (input_841272109.length == 0) {
#                     input_841272109 = cell_841272109.prev("div.nbinput");
#                 }
#                 input_841272109.hide();
#
#                 toggle_input_841272109 = function() {
#                     if (input_841272109.is(':hidden')) {
#                         input_841272109.slideDown();
#                         link_841272109[0].innerHTML = "Hide Input";
#                     } else {
#                         input_841272109.slideUp();
#                         link_841272109[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="183138974" href="javascript:toggle_input_183138974()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_183138974;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_183138974 = document.getElementById("183138974");
#                 var cell = link_183138974;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_183138974;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_183138974 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_183138974 = cell.previousElementSibling;
#                 }
#                 input_183138974.style.display = "none"; // hide
#
#                 toggle_input_183138974 = function() {
#                     if (input_183138974.style.display == "none") {
#                         input_183138974.style.display = ""; // show
#                         link_183138974.innerHTML = "Hide Input";
#                     } else {
#                         input_183138974.style.display = "none"; // hide
#                         link_183138974.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_183138974 = $("a[id='183138974']");
#                 var cell_183138974 = link_183138974.parents("div.cell:first");
#                 if (cell_183138974.length == 0) {
#                     cell_183138974 = link_183138974.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_183138974 = cell_183138974.children("div.input");
#                 if (input_183138974.length == 0) {
#                     input_183138974 = cell_183138974.prev("div.nbinput");
#                 }
#                 input_183138974.hide();
#
#                 toggle_input_183138974 = function() {
#                     if (input_183138974.is(':hidden')) {
#                         input_183138974.slideDown();
#                         link_183138974[0].innerHTML = "Hide Input";
#                     } else {
#                         input_183138974.slideUp();
#                         link_183138974[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1814833346" href="javascript:toggle_input_1814833346()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1814833346;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1814833346 = document.getElementById("1814833346");
#                 var cell = link_1814833346;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1814833346;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1814833346 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1814833346 = cell.previousElementSibling;
#                 }
#                 input_1814833346.style.display = "none"; // hide
#
#                 toggle_input_1814833346 = function() {
#                     if (input_1814833346.style.display == "none") {
#                         input_1814833346.style.display = ""; // show
#                         link_1814833346.innerHTML = "Hide Input";
#                     } else {
#                         input_1814833346.style.display = "none"; // hide
#                         link_1814833346.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1814833346 = $("a[id='1814833346']");
#                 var cell_1814833346 = link_1814833346.parents("div.cell:first");
#                 if (cell_1814833346.length == 0) {
#                     cell_1814833346 = link_1814833346.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1814833346 = cell_1814833346.children("div.input");
#                 if (input_1814833346.length == 0) {
#                     input_1814833346 = cell_1814833346.prev("div.nbinput");
#                 }
#                 input_1814833346.hide();
#
#                 toggle_input_1814833346 = function() {
#                     if (input_1814833346.is(':hidden')) {
#                         input_1814833346.slideDown();
#                         link_1814833346[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1814833346.slideUp();
#                         link_1814833346[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="963828404" href="javascript:toggle_input_963828404()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_963828404;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_963828404 = document.getElementById("963828404");
#                 var cell = link_963828404;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_963828404;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_963828404 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_963828404 = cell.previousElementSibling;
#                 }
#                 input_963828404.style.display = "none"; // hide
#
#                 toggle_input_963828404 = function() {
#                     if (input_963828404.style.display == "none") {
#                         input_963828404.style.display = ""; // show
#                         link_963828404.innerHTML = "Hide Input";
#                     } else {
#                         input_963828404.style.display = "none"; // hide
#                         link_963828404.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_963828404 = $("a[id='963828404']");
#                 var cell_963828404 = link_963828404.parents("div.cell:first");
#                 if (cell_963828404.length == 0) {
#                     cell_963828404 = link_963828404.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_963828404 = cell_963828404.children("div.input");
#                 if (input_963828404.length == 0) {
#                     input_963828404 = cell_963828404.prev("div.nbinput");
#                 }
#                 input_963828404.hide();
#
#                 toggle_input_963828404 = function() {
#                     if (input_963828404.is(':hidden')) {
#                         input_963828404.slideDown();
#                         link_963828404[0].innerHTML = "Hide Input";
#                     } else {
#                         input_963828404.slideUp();
#                         link_963828404[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1614015676" href="javascript:toggle_input_1614015676()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1614015676;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1614015676 = document.getElementById("1614015676");
#                 var cell = link_1614015676;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1614015676;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1614015676 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1614015676 = cell.previousElementSibling;
#                 }
#                 input_1614015676.style.display = "none"; // hide
#
#                 toggle_input_1614015676 = function() {
#                     if (input_1614015676.style.display == "none") {
#                         input_1614015676.style.display = ""; // show
#                         link_1614015676.innerHTML = "Hide Input";
#                     } else {
#                         input_1614015676.style.display = "none"; // hide
#                         link_1614015676.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1614015676 = $("a[id='1614015676']");
#                 var cell_1614015676 = link_1614015676.parents("div.cell:first");
#                 if (cell_1614015676.length == 0) {
#                     cell_1614015676 = link_1614015676.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1614015676 = cell_1614015676.children("div.input");
#                 if (input_1614015676.length == 0) {
#                     input_1614015676 = cell_1614015676.prev("div.nbinput");
#                 }
#                 input_1614015676.hide();
#
#                 toggle_input_1614015676 = function() {
#                     if (input_1614015676.is(':hidden')) {
#                         input_1614015676.slideDown();
#                         link_1614015676[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1614015676.slideUp();
#                         link_1614015676[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1599173302" href="javascript:toggle_input_1599173302()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1599173302;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1599173302 = document.getElementById("1599173302");
#                 var cell = link_1599173302;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1599173302;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1599173302 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1599173302 = cell.previousElementSibling;
#                 }
#                 input_1599173302.style.display = "none"; // hide
#
#                 toggle_input_1599173302 = function() {
#                     if (input_1599173302.style.display == "none") {
#                         input_1599173302.style.display = ""; // show
#                         link_1599173302.innerHTML = "Hide Input";
#                     } else {
#                         input_1599173302.style.display = "none"; // hide
#                         link_1599173302.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1599173302 = $("a[id='1599173302']");
#                 var cell_1599173302 = link_1599173302.parents("div.cell:first");
#                 if (cell_1599173302.length == 0) {
#                     cell_1599173302 = link_1599173302.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1599173302 = cell_1599173302.children("div.input");
#                 if (input_1599173302.length == 0) {
#                     input_1599173302 = cell_1599173302.prev("div.nbinput");
#                 }
#                 input_1599173302.hide();
#
#                 toggle_input_1599173302 = function() {
#                     if (input_1599173302.is(':hidden')) {
#                         input_1599173302.slideDown();
#                         link_1599173302[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1599173302.slideUp();
#                         link_1599173302[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2093524664" href="javascript:toggle_input_2093524664()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2093524664;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2093524664 = document.getElementById("2093524664");
#                 var cell = link_2093524664;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2093524664;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2093524664 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2093524664 = cell.previousElementSibling;
#                 }
#                 input_2093524664.style.display = "none"; // hide
#
#                 toggle_input_2093524664 = function() {
#                     if (input_2093524664.style.display == "none") {
#                         input_2093524664.style.display = ""; // show
#                         link_2093524664.innerHTML = "Hide Input";
#                     } else {
#                         input_2093524664.style.display = "none"; // hide
#                         link_2093524664.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2093524664 = $("a[id='2093524664']");
#                 var cell_2093524664 = link_2093524664.parents("div.cell:first");
#                 if (cell_2093524664.length == 0) {
#                     cell_2093524664 = link_2093524664.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2093524664 = cell_2093524664.children("div.input");
#                 if (input_2093524664.length == 0) {
#                     input_2093524664 = cell_2093524664.prev("div.nbinput");
#                 }
#                 input_2093524664.hide();
#
#                 toggle_input_2093524664 = function() {
#                     if (input_2093524664.is(':hidden')) {
#                         input_2093524664.slideDown();
#                         link_2093524664[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2093524664.slideUp();
#                         link_2093524664[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="2060746202" href="javascript:toggle_input_2060746202()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2060746202;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2060746202 = document.getElementById("2060746202");
#                 var cell = link_2060746202;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2060746202;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2060746202 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2060746202 = cell.previousElementSibling;
#                 }
#                 input_2060746202.style.display = "none"; // hide
#
#                 toggle_input_2060746202 = function() {
#                     if (input_2060746202.style.display == "none") {
#                         input_2060746202.style.display = ""; // show
#                         link_2060746202.innerHTML = "Hide Input";
#                     } else {
#                         input_2060746202.style.display = "none"; // hide
#                         link_2060746202.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2060746202 = $("a[id='2060746202']");
#                 var cell_2060746202 = link_2060746202.parents("div.cell:first");
#                 if (cell_2060746202.length == 0) {
#                     cell_2060746202 = link_2060746202.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2060746202 = cell_2060746202.children("div.input");
#                 if (input_2060746202.length == 0) {
#                     input_2060746202 = cell_2060746202.prev("div.nbinput");
#                 }
#                 input_2060746202.hide();
#
#                 toggle_input_2060746202 = function() {
#                     if (input_2060746202.is(':hidden')) {
#                         input_2060746202.slideDown();
#                         link_2060746202[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2060746202.slideUp();
#                         link_2060746202[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
