# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="759293300" href="javascript:toggle_input_759293300()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_759293300;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_759293300 = document.getElementById("759293300");
#                 var cell = link_759293300;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_759293300;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_759293300 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_759293300 = cell.previousElementSibling;
#                 }
#                 input_759293300.style.display = "none"; // hide
#
#                 toggle_input_759293300 = function() {
#                     if (input_759293300.style.display == "none") {
#                         input_759293300.style.display = ""; // show
#                         link_759293300.innerHTML = "Hide Input";
#                     } else {
#                         input_759293300.style.display = "none"; // hide
#                         link_759293300.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_759293300 = $("a[id='759293300']");
#                 var cell_759293300 = link_759293300.parents("div.cell:first");
#                 if (cell_759293300.length == 0) {
#                     cell_759293300 = link_759293300.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_759293300 = cell_759293300.children("div.input");
#                 if (input_759293300.length == 0) {
#                     input_759293300 = cell_759293300.prev("div.nbinput");
#                 }
#                 input_759293300.hide();
#
#                 toggle_input_759293300 = function() {
#                     if (input_759293300.is(':hidden')) {
#                         input_759293300.slideDown();
#                         link_759293300[0].innerHTML = "Hide Input";
#                     } else {
#                         input_759293300.slideUp();
#                         link_759293300[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1373891978" href="javascript:toggle_input_1373891978()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1373891978;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1373891978 = document.getElementById("1373891978");
#                 var cell = link_1373891978;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1373891978;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1373891978 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1373891978 = cell.previousElementSibling;
#                 }
#                 input_1373891978.style.display = "none"; // hide
#
#                 toggle_input_1373891978 = function() {
#                     if (input_1373891978.style.display == "none") {
#                         input_1373891978.style.display = ""; // show
#                         link_1373891978.innerHTML = "Hide Input";
#                     } else {
#                         input_1373891978.style.display = "none"; // hide
#                         link_1373891978.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1373891978 = $("a[id='1373891978']");
#                 var cell_1373891978 = link_1373891978.parents("div.cell:first");
#                 if (cell_1373891978.length == 0) {
#                     cell_1373891978 = link_1373891978.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1373891978 = cell_1373891978.children("div.input");
#                 if (input_1373891978.length == 0) {
#                     input_1373891978 = cell_1373891978.prev("div.nbinput");
#                 }
#                 input_1373891978.hide();
#
#                 toggle_input_1373891978 = function() {
#                     if (input_1373891978.is(':hidden')) {
#                         input_1373891978.slideDown();
#                         link_1373891978[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1373891978.slideUp();
#                         link_1373891978[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1982690828" href="javascript:toggle_input_1982690828()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1982690828;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1982690828 = document.getElementById("1982690828");
#                 var cell = link_1982690828;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1982690828;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1982690828 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1982690828 = cell.previousElementSibling;
#                 }
#                 input_1982690828.style.display = "none"; // hide
#
#                 toggle_input_1982690828 = function() {
#                     if (input_1982690828.style.display == "none") {
#                         input_1982690828.style.display = ""; // show
#                         link_1982690828.innerHTML = "Hide Input";
#                     } else {
#                         input_1982690828.style.display = "none"; // hide
#                         link_1982690828.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1982690828 = $("a[id='1982690828']");
#                 var cell_1982690828 = link_1982690828.parents("div.cell:first");
#                 if (cell_1982690828.length == 0) {
#                     cell_1982690828 = link_1982690828.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1982690828 = cell_1982690828.children("div.input");
#                 if (input_1982690828.length == 0) {
#                     input_1982690828 = cell_1982690828.prev("div.nbinput");
#                 }
#                 input_1982690828.hide();
#
#                 toggle_input_1982690828 = function() {
#                     if (input_1982690828.is(':hidden')) {
#                         input_1982690828.slideDown();
#                         link_1982690828[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1982690828.slideUp();
#                         link_1982690828[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="309000010" href="javascript:toggle_input_309000010()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_309000010;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_309000010 = document.getElementById("309000010");
#                 var cell = link_309000010;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_309000010;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_309000010 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_309000010 = cell.previousElementSibling;
#                 }
#                 input_309000010.style.display = "none"; // hide
#
#                 toggle_input_309000010 = function() {
#                     if (input_309000010.style.display == "none") {
#                         input_309000010.style.display = ""; // show
#                         link_309000010.innerHTML = "Hide Input";
#                     } else {
#                         input_309000010.style.display = "none"; // hide
#                         link_309000010.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_309000010 = $("a[id='309000010']");
#                 var cell_309000010 = link_309000010.parents("div.cell:first");
#                 if (cell_309000010.length == 0) {
#                     cell_309000010 = link_309000010.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_309000010 = cell_309000010.children("div.input");
#                 if (input_309000010.length == 0) {
#                     input_309000010 = cell_309000010.prev("div.nbinput");
#                 }
#                 input_309000010.hide();
#
#                 toggle_input_309000010 = function() {
#                     if (input_309000010.is(':hidden')) {
#                         input_309000010.slideDown();
#                         link_309000010[0].innerHTML = "Hide Input";
#                     } else {
#                         input_309000010.slideUp();
#                         link_309000010[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="125897697" href="javascript:toggle_input_125897697()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_125897697;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_125897697 = document.getElementById("125897697");
#                 var cell = link_125897697;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_125897697;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_125897697 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_125897697 = cell.previousElementSibling;
#                 }
#                 input_125897697.style.display = "none"; // hide
#
#                 toggle_input_125897697 = function() {
#                     if (input_125897697.style.display == "none") {
#                         input_125897697.style.display = ""; // show
#                         link_125897697.innerHTML = "Hide Input";
#                     } else {
#                         input_125897697.style.display = "none"; // hide
#                         link_125897697.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_125897697 = $("a[id='125897697']");
#                 var cell_125897697 = link_125897697.parents("div.cell:first");
#                 if (cell_125897697.length == 0) {
#                     cell_125897697 = link_125897697.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_125897697 = cell_125897697.children("div.input");
#                 if (input_125897697.length == 0) {
#                     input_125897697 = cell_125897697.prev("div.nbinput");
#                 }
#                 input_125897697.hide();
#
#                 toggle_input_125897697 = function() {
#                     if (input_125897697.is(':hidden')) {
#                         input_125897697.slideDown();
#                         link_125897697[0].innerHTML = "Hide Input";
#                     } else {
#                         input_125897697.slideUp();
#                         link_125897697[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="168657208" href="javascript:toggle_input_168657208()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_168657208;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_168657208 = document.getElementById("168657208");
#                 var cell = link_168657208;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_168657208;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_168657208 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_168657208 = cell.previousElementSibling;
#                 }
#                 input_168657208.style.display = "none"; // hide
#
#                 toggle_input_168657208 = function() {
#                     if (input_168657208.style.display == "none") {
#                         input_168657208.style.display = ""; // show
#                         link_168657208.innerHTML = "Hide Input";
#                     } else {
#                         input_168657208.style.display = "none"; // hide
#                         link_168657208.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_168657208 = $("a[id='168657208']");
#                 var cell_168657208 = link_168657208.parents("div.cell:first");
#                 if (cell_168657208.length == 0) {
#                     cell_168657208 = link_168657208.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_168657208 = cell_168657208.children("div.input");
#                 if (input_168657208.length == 0) {
#                     input_168657208 = cell_168657208.prev("div.nbinput");
#                 }
#                 input_168657208.hide();
#
#                 toggle_input_168657208 = function() {
#                     if (input_168657208.is(':hidden')) {
#                         input_168657208.slideDown();
#                         link_168657208[0].innerHTML = "Hide Input";
#                     } else {
#                         input_168657208.slideUp();
#                         link_168657208[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1980765836" href="javascript:toggle_input_1980765836()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1980765836;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1980765836 = document.getElementById("1980765836");
#                 var cell = link_1980765836;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1980765836;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1980765836 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1980765836 = cell.previousElementSibling;
#                 }
#                 input_1980765836.style.display = "none"; // hide
#
#                 toggle_input_1980765836 = function() {
#                     if (input_1980765836.style.display == "none") {
#                         input_1980765836.style.display = ""; // show
#                         link_1980765836.innerHTML = "Hide Input";
#                     } else {
#                         input_1980765836.style.display = "none"; // hide
#                         link_1980765836.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1980765836 = $("a[id='1980765836']");
#                 var cell_1980765836 = link_1980765836.parents("div.cell:first");
#                 if (cell_1980765836.length == 0) {
#                     cell_1980765836 = link_1980765836.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1980765836 = cell_1980765836.children("div.input");
#                 if (input_1980765836.length == 0) {
#                     input_1980765836 = cell_1980765836.prev("div.nbinput");
#                 }
#                 input_1980765836.hide();
#
#                 toggle_input_1980765836 = function() {
#                     if (input_1980765836.is(':hidden')) {
#                         input_1980765836.slideDown();
#                         link_1980765836[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1980765836.slideUp();
#                         link_1980765836[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="547950708" href="javascript:toggle_input_547950708()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_547950708;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_547950708 = document.getElementById("547950708");
#                 var cell = link_547950708;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_547950708;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_547950708 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_547950708 = cell.previousElementSibling;
#                 }
#                 input_547950708.style.display = "none"; // hide
#
#                 toggle_input_547950708 = function() {
#                     if (input_547950708.style.display == "none") {
#                         input_547950708.style.display = ""; // show
#                         link_547950708.innerHTML = "Hide Input";
#                     } else {
#                         input_547950708.style.display = "none"; // hide
#                         link_547950708.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_547950708 = $("a[id='547950708']");
#                 var cell_547950708 = link_547950708.parents("div.cell:first");
#                 if (cell_547950708.length == 0) {
#                     cell_547950708 = link_547950708.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_547950708 = cell_547950708.children("div.input");
#                 if (input_547950708.length == 0) {
#                     input_547950708 = cell_547950708.prev("div.nbinput");
#                 }
#                 input_547950708.hide();
#
#                 toggle_input_547950708 = function() {
#                     if (input_547950708.is(':hidden')) {
#                         input_547950708.slideDown();
#                         link_547950708[0].innerHTML = "Hide Input";
#                     } else {
#                         input_547950708.slideUp();
#                         link_547950708[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="431018256" href="javascript:toggle_input_431018256()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_431018256;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_431018256 = document.getElementById("431018256");
#                 var cell = link_431018256;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_431018256;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_431018256 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_431018256 = cell.previousElementSibling;
#                 }
#                 input_431018256.style.display = "none"; // hide
#
#                 toggle_input_431018256 = function() {
#                     if (input_431018256.style.display == "none") {
#                         input_431018256.style.display = ""; // show
#                         link_431018256.innerHTML = "Hide Input";
#                     } else {
#                         input_431018256.style.display = "none"; // hide
#                         link_431018256.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_431018256 = $("a[id='431018256']");
#                 var cell_431018256 = link_431018256.parents("div.cell:first");
#                 if (cell_431018256.length == 0) {
#                     cell_431018256 = link_431018256.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_431018256 = cell_431018256.children("div.input");
#                 if (input_431018256.length == 0) {
#                     input_431018256 = cell_431018256.prev("div.nbinput");
#                 }
#                 input_431018256.hide();
#
#                 toggle_input_431018256 = function() {
#                     if (input_431018256.is(':hidden')) {
#                         input_431018256.slideDown();
#                         link_431018256[0].innerHTML = "Hide Input";
#                     } else {
#                         input_431018256.slideUp();
#                         link_431018256[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="459284299" href="javascript:toggle_input_459284299()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_459284299;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_459284299 = document.getElementById("459284299");
#                 var cell = link_459284299;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_459284299;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_459284299 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_459284299 = cell.previousElementSibling;
#                 }
#                 input_459284299.style.display = "none"; // hide
#
#                 toggle_input_459284299 = function() {
#                     if (input_459284299.style.display == "none") {
#                         input_459284299.style.display = ""; // show
#                         link_459284299.innerHTML = "Hide Input";
#                     } else {
#                         input_459284299.style.display = "none"; // hide
#                         link_459284299.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_459284299 = $("a[id='459284299']");
#                 var cell_459284299 = link_459284299.parents("div.cell:first");
#                 if (cell_459284299.length == 0) {
#                     cell_459284299 = link_459284299.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_459284299 = cell_459284299.children("div.input");
#                 if (input_459284299.length == 0) {
#                     input_459284299 = cell_459284299.prev("div.nbinput");
#                 }
#                 input_459284299.hide();
#
#                 toggle_input_459284299 = function() {
#                     if (input_459284299.is(':hidden')) {
#                         input_459284299.slideDown();
#                         link_459284299[0].innerHTML = "Hide Input";
#                     } else {
#                         input_459284299.slideUp();
#                         link_459284299[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1464868996" href="javascript:toggle_input_1464868996()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1464868996;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1464868996 = document.getElementById("1464868996");
#                 var cell = link_1464868996;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1464868996;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1464868996 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1464868996 = cell.previousElementSibling;
#                 }
#                 input_1464868996.style.display = "none"; // hide
#
#                 toggle_input_1464868996 = function() {
#                     if (input_1464868996.style.display == "none") {
#                         input_1464868996.style.display = ""; // show
#                         link_1464868996.innerHTML = "Hide Input";
#                     } else {
#                         input_1464868996.style.display = "none"; // hide
#                         link_1464868996.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1464868996 = $("a[id='1464868996']");
#                 var cell_1464868996 = link_1464868996.parents("div.cell:first");
#                 if (cell_1464868996.length == 0) {
#                     cell_1464868996 = link_1464868996.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1464868996 = cell_1464868996.children("div.input");
#                 if (input_1464868996.length == 0) {
#                     input_1464868996 = cell_1464868996.prev("div.nbinput");
#                 }
#                 input_1464868996.hide();
#
#                 toggle_input_1464868996 = function() {
#                     if (input_1464868996.is(':hidden')) {
#                         input_1464868996.slideDown();
#                         link_1464868996[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1464868996.slideUp();
#                         link_1464868996[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1139749719" href="javascript:toggle_input_1139749719()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1139749719;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1139749719 = document.getElementById("1139749719");
#                 var cell = link_1139749719;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1139749719;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1139749719 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1139749719 = cell.previousElementSibling;
#                 }
#                 input_1139749719.style.display = "none"; // hide
#
#                 toggle_input_1139749719 = function() {
#                     if (input_1139749719.style.display == "none") {
#                         input_1139749719.style.display = ""; // show
#                         link_1139749719.innerHTML = "Hide Input";
#                     } else {
#                         input_1139749719.style.display = "none"; // hide
#                         link_1139749719.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1139749719 = $("a[id='1139749719']");
#                 var cell_1139749719 = link_1139749719.parents("div.cell:first");
#                 if (cell_1139749719.length == 0) {
#                     cell_1139749719 = link_1139749719.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1139749719 = cell_1139749719.children("div.input");
#                 if (input_1139749719.length == 0) {
#                     input_1139749719 = cell_1139749719.prev("div.nbinput");
#                 }
#                 input_1139749719.hide();
#
#                 toggle_input_1139749719 = function() {
#                     if (input_1139749719.is(':hidden')) {
#                         input_1139749719.slideDown();
#                         link_1139749719[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1139749719.slideUp();
#                         link_1139749719[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="82178649" href="javascript:toggle_input_82178649()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_82178649;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_82178649 = document.getElementById("82178649");
#                 var cell = link_82178649;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_82178649;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_82178649 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_82178649 = cell.previousElementSibling;
#                 }
#                 input_82178649.style.display = "none"; // hide
#
#                 toggle_input_82178649 = function() {
#                     if (input_82178649.style.display == "none") {
#                         input_82178649.style.display = ""; // show
#                         link_82178649.innerHTML = "Hide Input";
#                     } else {
#                         input_82178649.style.display = "none"; // hide
#                         link_82178649.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_82178649 = $("a[id='82178649']");
#                 var cell_82178649 = link_82178649.parents("div.cell:first");
#                 if (cell_82178649.length == 0) {
#                     cell_82178649 = link_82178649.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_82178649 = cell_82178649.children("div.input");
#                 if (input_82178649.length == 0) {
#                     input_82178649 = cell_82178649.prev("div.nbinput");
#                 }
#                 input_82178649.hide();
#
#                 toggle_input_82178649 = function() {
#                     if (input_82178649.is(':hidden')) {
#                         input_82178649.slideDown();
#                         link_82178649[0].innerHTML = "Hide Input";
#                     } else {
#                         input_82178649.slideUp();
#                         link_82178649[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
